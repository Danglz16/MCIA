# %% [markdown]
# Algoritmos Metaheuristicos
# Tarea 4 - Organizacion de Horarios
# Autor: Ing. Daniel Eduardo González Alvarado
# Profesor: Dr. Marco Aceves

# %% [markdown]
# # Importar Librerias

# %% [markdown]
# ## Base de Datos
