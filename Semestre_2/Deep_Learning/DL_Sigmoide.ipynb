# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

z = np.linspace(-10, 10, 1000)
s = sigmoid(z)
plt.figure(figsize=(6, 4))
plt.grid(True)
plt.plot(z, s)
